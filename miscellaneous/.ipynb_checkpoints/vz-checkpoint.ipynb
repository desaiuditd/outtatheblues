# %%
import pandas as pd
# %matplotlib inline
import seaborn

# %%
df = pd.read_csv('/Users/Rohit/outtatheblues/miscellaneous/sample.csv')

# %%
df.head()
# Out:
#      Date    C1    C2
# 0  1/1/17  1.30  7.60
# 1  1/2/17  1.27  7.53
# 2  1/3/17  1.29  7.54
# 3  1/4/17  1.31  7.60
# 4  1/5/17  1.30  7.66

# %%
df1 = df[['Date', 'C1']]
fig = df1.plot(legend=False,figsize=(40,10),fontsize=(18))
fig.savefig('/pics/CheekAreaVariation')

# %%
df2 = df[['Date', 'C2']]
df2.plot(legend=False,figsize=(40,10),fontsize=(18))
fig.savefig('/pics/FeatureLengthVariation')
